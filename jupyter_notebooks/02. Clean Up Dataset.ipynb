# %% [markdown]
# # **Clean Up Dataset**

# %% [markdown]
# # Change working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/workspace/BikeSharingRental/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory.
#
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/workspace/BikeSharingRental'

# %% [markdown]
# # Import Libraries

# %%
! pip install tensorflow==2.2.0
import tensorflow as tf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: tensorflow-cpu==2.6.0 in /workspace/.pip-modules/lib/python3.8/site-packages (2.6.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (1.12.1)
# Requirement already satisfied: tensorboard~=2.6 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (2.12.1)
# Requirement already satisfied: clang~=5.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (5.0)
# Requirement already satisfied: wheel~=0.35 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (0.37.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (1.12)
# Requirement already satisfied: h5py~=3.1.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (3.1.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (3.3.0)
# Requirement already satisfied: keras~=2.6 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (2.12.0)
# Requirement already satisfied: protobuf>=3.9.2 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (3.20.0)
# Requirement already satisfied: tensorflow-estimator~=2.6 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (2.12.0)
# Requirement already satisfied: termcolor~=1.1.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (1.1.0)
# Requirement already satisfied: six~=1.15.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (1.15.0)
# Requirement already satisfied: gast==0.4.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (0.4.0)
# Requirement already satisfied: google-pasta~=0.2 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.37.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (1.53.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (3.7.4.3)
# Requirement already satisfied: astunparse~=1.6.3 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (1.6.3)
# Requirement already satisfied: numpy~=1.19.2 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (1.19.5)
# Requirement already satisfied: absl-py~=0.10 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow-cpu==2.6.0) (0.15.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow-cpu==2.6.0) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow-cpu==2.6.0) (2.17.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow-cpu==2.6.0) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow-cpu==2.6.0) (2.26.0)
# Requirement already satisfied: markdown>=2.6.8 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow-cpu==2.6.0) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow-cpu==2.6.0) (0.7.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow-cpu==2.6.0) (1.0.0)
# Requirement already satisfied: setuptools>=41.0.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow-cpu==2.6.0) (67.6.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /workspace/.pip-modules/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-cpu==2.6.0) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-cpu==2.6.0) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-cpu==2.6.0) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard~=2.6->tensorflow-cpu==2.6.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow-cpu==2.6.0) (6.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow-cpu==2.6.0) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow-cpu==2.6.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow-cpu==2.6.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow-cpu==2.6.0) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard~=2.6->tensorflow-cpu==2.6.0) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow-cpu==2.6.0) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /workspace/.pip-modules/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow-cpu==2.6.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard~=2.6->tensorflow-cpu==2.6.0) (3.2.2)

# %% [markdown]
# # Load and Inspect Kaggle data

# %%
bike = pd.read_csv('inputs/datasets/raw/bike_sharing_daily.csv')

# %%
bike.head(5)
# Out:
#    instant    dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  1/1/2011       1   0     1        0        6           0
# 1        2  1/2/2011       1   0     1        0        0           0
# 2        3  1/3/2011       1   0     1        0        1           1
# 3        4  1/4/2011       1   0     1        0        2           1
# 4        5  1/5/2011       1   0     1        0        3           1
#
#    weathersit      temp       hum  windspeed  casual  registered   cnt
# 0           2  0.344167  0.805833   0.160446     331         654   985
# 1           2  0.363478  0.696087   0.248539     131         670   801
# 2           1  0.196364  0.437273   0.248309     120        1229  1349
# 3           1  0.200000  0.590435   0.160296     108        1454  1562
# 4           1  0.226957  0.436957   0.186900      82        1518  1600

# %% [markdown]
# * Check if there is any null element

# %%
sns.heatmap(bike.isnull())
# Out:
# <AxesSubplot:>

# %%
bike = bike.drop(labels= ['instant'], axis=1)

# %%
bike
# Out:
#          dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0      1/1/2011       1   0     1        0        6           0           2
# 1      1/2/2011       1   0     1        0        0           0           2
# 2      1/3/2011       1   0     1        0        1           1           1
# 3      1/4/2011       1   0     1        0        2           1           1
# 4      1/5/2011       1   0     1        0        3           1           1
# ..          ...     ...  ..   ...      ...      ...         ...         ...
# 726  12/27/2012       1   1    12        0        4           1           2
# 727  12/28/2012       1   1    12        0        5           1           2
# 728  12/29/2012       1   1    12        0        6           0           2
# 729  12/30/2012       1   1    12        0        0           0           1
# 730  12/31/2012       1   1    12        0        1           1           2
#
#          temp       hum  windspeed  casual  registered   cnt
# 0    0.344167  0.805833   0.160446     331         654   985
# 1    0.363478  0.696087   0.248539     131         670   801
# 2    0.196364  0.437273   0.248309     120        1229  1349
# 3    0.200000  0.590435   0.160296     108        1454  1562
# 4    0.226957  0.436957   0.186900      82        1518  1600
# ..        ...       ...        ...     ...         ...   ...
# 726  0.254167  0.652917   0.350133     247        1867  2114
# 727  0.253333  0.590000   0.155471     644        2451  3095
# 728  0.253333  0.752917   0.124383     159        1182  1341
# 729  0.255833  0.483333   0.350754     364        1432  1796
# 730  0.215833  0.577500   0.154846     439        2290  2729
#
# [731 rows x 14 columns]

# %%
bike = bike.drop(labels= ['casual', 'registered'], axis = 1)

# %%
bike
# Out:
#          dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0      1/1/2011       1   0     1        0        6           0           2
# 1      1/2/2011       1   0     1        0        0           0           2
# 2      1/3/2011       1   0     1        0        1           1           1
# 3      1/4/2011       1   0     1        0        2           1           1
# 4      1/5/2011       1   0     1        0        3           1           1
# ..          ...     ...  ..   ...      ...      ...         ...         ...
# 726  12/27/2012       1   1    12        0        4           1           2
# 727  12/28/2012       1   1    12        0        5           1           2
# 728  12/29/2012       1   1    12        0        6           0           2
# 729  12/30/2012       1   1    12        0        0           0           1
# 730  12/31/2012       1   1    12        0        1           1           2
#
#          temp       hum  windspeed   cnt
# 0    0.344167  0.805833   0.160446   985
# 1    0.363478  0.696087   0.248539   801
# 2    0.196364  0.437273   0.248309  1349
# 3    0.200000  0.590435   0.160296  1562
# 4    0.226957  0.436957   0.186900  1600
# ..        ...       ...        ...   ...
# 726  0.254167  0.652917   0.350133  2114
# 727  0.253333  0.590000   0.155471  3095
# 728  0.253333  0.752917   0.124383  1341
# 729  0.255833  0.483333   0.350754  1796
# 730  0.215833  0.577500   0.154846  2729
#
# [731 rows x 12 columns]

# %% [markdown]
# * Convert dtday to Datetime Format

# %%
bike.dteday = pd.to_datetime(bike.dteday, format= '%m/%d/%Y')

# %%
bike
# Out:
#         dteday  season  yr  mnth  holiday  weekday  workingday  weathersit  \
# 0   2011-01-01       1   0     1        0        6           0           2
# 1   2011-01-02       1   0     1        0        0           0           2
# 2   2011-01-03       1   0     1        0        1           1           1
# 3   2011-01-04       1   0     1        0        2           1           1
# 4   2011-01-05       1   0     1        0        3           1           1
# ..         ...     ...  ..   ...      ...      ...         ...         ...
# 726 2012-12-27       1   1    12        0        4           1           2
# 727 2012-12-28       1   1    12        0        5           1           2
# 728 2012-12-29       1   1    12        0        6           0           2
# 729 2012-12-30       1   1    12        0        0           0           1
# 730 2012-12-31       1   1    12        0        1           1           2
#
#          temp       hum  windspeed   cnt
# 0    0.344167  0.805833   0.160446   985
# 1    0.363478  0.696087   0.248539   801
# 2    0.196364  0.437273   0.248309  1349
# 3    0.200000  0.590435   0.160296  1562
# 4    0.226957  0.436957   0.186900  1600
# ..        ...       ...        ...   ...
# 726  0.254167  0.652917   0.350133  2114
# 727  0.253333  0.590000   0.155471  3095
# 728  0.253333  0.752917   0.124383  1341
# 729  0.255833  0.483333   0.350754  1796
# 730  0.215833  0.577500   0.154846  2729
#
# [731 rows x 12 columns]

# %% [markdown]
# * Use Datetime column as index

# %%
bike.index = pd.DatetimeIndex(bike.dteday)

# %%
bike
# Out:
#                dteday  season  yr  mnth  holiday  weekday  workingday  \
# dteday
# 2011-01-01 2011-01-01       1   0     1        0        6           0
# 2011-01-02 2011-01-02       1   0     1        0        0           0
# 2011-01-03 2011-01-03       1   0     1        0        1           1
# 2011-01-04 2011-01-04       1   0     1        0        2           1
# 2011-01-05 2011-01-05       1   0     1        0        3           1
# ...               ...     ...  ..   ...      ...      ...         ...
# 2012-12-27 2012-12-27       1   1    12        0        4           1
# 2012-12-28 2012-12-28       1   1    12        0        5           1
# 2012-12-29 2012-12-29       1   1    12        0        6           0
# 2012-12-30 2012-12-30       1   1    12        0        0           0
# 2012-12-31 2012-12-31       1   1    12        0        1           1
#
#             weathersit      temp       hum  windspeed   cnt
# dteday
# 2011-01-01           2  0.344167  0.805833   0.160446   985
# 2011-01-02           2  0.363478  0.696087   0.248539   801
# 2011-01-03           1  0.196364  0.437273   0.248309  1349
# 2011-01-04           1  0.200000  0.590435   0.160296  1562
# 2011-01-05           1  0.226957  0.436957   0.186900  1600
# ...                ...       ...       ...        ...   ...
# 2012-12-27           2  0.254167  0.652917   0.350133  2114
# 2012-12-28           2  0.253333  0.590000   0.155471  3095
# 2012-12-29           2  0.253333  0.752917   0.124383  1341
# 2012-12-30           1  0.255833  0.483333   0.350754  1796
# 2012-12-31           2  0.215833  0.577500   0.154846  2729
#
# [731 rows x 12 columns]

# %%
bike = bike.drop(labels= ['dteday'], axis=1)

# %%
bike
# Out:
#             season  yr  mnth  holiday  weekday  workingday  weathersit  \
# dteday
# 2011-01-01       1   0     1        0        6           0           2
# 2011-01-02       1   0     1        0        0           0           2
# 2011-01-03       1   0     1        0        1           1           1
# 2011-01-04       1   0     1        0        2           1           1
# 2011-01-05       1   0     1        0        3           1           1
# ...            ...  ..   ...      ...      ...         ...         ...
# 2012-12-27       1   1    12        0        4           1           2
# 2012-12-28       1   1    12        0        5           1           2
# 2012-12-29       1   1    12        0        6           0           2
# 2012-12-30       1   1    12        0        0           0           1
# 2012-12-31       1   1    12        0        1           1           2
#
#                 temp       hum  windspeed   cnt
# dteday
# 2011-01-01  0.344167  0.805833   0.160446   985
# 2011-01-02  0.363478  0.696087   0.248539   801
# 2011-01-03  0.196364  0.437273   0.248309  1349
# 2011-01-04  0.200000  0.590435   0.160296  1562
# 2011-01-05  0.226957  0.436957   0.186900  1600
# ...              ...       ...        ...   ...
# 2012-12-27  0.254167  0.652917   0.350133  2114
# 2012-12-28  0.253333  0.590000   0.155471  3095
# 2012-12-29  0.253333  0.752917   0.124383  1341
# 2012-12-30  0.255833  0.483333   0.350754  1796
# 2012-12-31  0.215833  0.577500   0.154846  2729
#
# [731 rows x 11 columns]

# %% [markdown]
# # Push files to Repo

# %%
import os
try:
  os.makedirs(name='outputs/datasets/collection') # create here your folder
  # os.makedirs(name='')
except Exception as e:
  print(e)

bike.to_csv(f"outputs/datasets/collection/bike_sharing_daily.csv", index=False)
# Out:
# [Errno 17] File exists: 'outputs/datasets/collection'
